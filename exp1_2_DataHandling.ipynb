# %% [markdown]
# <a href="https://colab.research.google.com/github/DineshKumarVarada/ml/blob/main/exp1_2_DataHandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as nd
import matplotlib.pyplot as md
import seaborn as sb

# %%
dataset=pd.read_csv('/content/JEE_Dropout_After_Class_12.csv')#!

# %%
dataset.shape#!
# Out:
# (5000, 15)

# %%
dataset.head(  )#!
# Out:
#    jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0           78.95               59.22                59.86         CBSE
# 1           70.06               58.75                64.33        State
# 2           81.07               37.27                60.83         ICSE
# 3           93.32               60.72                69.33         ICSE
# 4           68.72               77.73                82.37         CBSE
#
#    class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0             70.09              1            FIITJEE                5.4
# 1             78.00              1            FIITJEE                5.5
# 2             64.36              1            FIITJEE                7.0
# 3             73.21              1            FIITJEE                2.1
# 4             89.02              1              Allen                6.3
#
#   family_income parent_education location_type peer_pressure_level  \
# ...

# %%
dataset.tail()#!
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 4995           71.31               86.82                57.08        State
# 4996           81.96               34.03                82.85         CBSE
# 4997          100.00               54.71                83.75         CBSE
# 4998           83.31               73.93                57.39         CBSE
# 4999           60.13               76.31                66.15        State
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 4995             84.45              1            FIITJEE                4.7
# 4996             73.02              2              Local                4.7
# 4997             77.87              2                NaN                6.3
# 4998             62.25              1              Allen                4.0
# 4999             94.90              2            FIITJEE                2.1
#
# ...

# %%
data_min=nd.min(dataset['jee_main_score'])#2

# %%
print(data_min)
# Out:
# 26.62

# %%
data_max=nd.max(dataset['jee_main_score'])#2
print(data_max)
# Out:
# 100.0

# %%
dataset.nunique()
# Out:
# jee_main_score          3113
# jee_advanced_score      3304
# mock_test_score_avg     3023
# school_board               3
# class_12_percent        2776
# attempt_count              2
# coaching_institute         3
# daily_study_hours        101
# family_income              3
# parent_education           4
# location_type              3
# peer_pressure_level        3
# mental_health_issues       2
# admission_taken            2
# dropout                    2
# dtype: int64

# %%
dataset.describe()
# Out:
#        jee_main_score  jee_advanced_score  mock_test_score_avg  \
# count     5000.000000         5000.000000          5000.000000
# mean        71.961226           65.736404            68.110756
# std         13.668497           15.909248            11.938849
# min         26.620000            3.240000            27.490000
# 25%         62.790000           55.017500            60.070000
# 50%         72.190000           65.720000            68.120000
# 75%         81.322500           76.835000            76.110000
# max        100.000000          100.000000           100.000000
#
#        class_12_percent  attempt_count  daily_study_hours      dropout
# count       5000.000000    5000.000000        5000.000000  5000.000000
# mean          74.957400       1.504600           4.483860     0.207200
# std            9.885309       0.500029           1.984723     0.405341
# min           50.000000       1.000000           0.000000     0.000000
# ...

# %%
dataset.memory_usage()
# Out:
# Index                     132
# jee_main_score          40000
# jee_advanced_score      40000
# mock_test_score_avg     40000
# school_board            40000
# class_12_percent        40000
# attempt_count           40000
# coaching_institute      40000
# daily_study_hours       40000
# family_income           40000
# parent_education        40000
# location_type           40000
# peer_pressure_level     40000
# mental_health_issues    40000
# admission_taken         40000
# dropout                 40000
# dtype: int64

# %%
data=dataset.copy()

# %%
print(data)
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0              78.95               59.22                59.86         CBSE
# 1              70.06               58.75                64.33        State
# 2              81.07               37.27                60.83         ICSE
# 3              93.32               60.72                69.33         ICSE
# 4              68.72               77.73                82.37         CBSE
# ...              ...                 ...                  ...          ...
# 4995           71.31               86.82                57.08        State
# 4996           81.96               34.03                82.85         CBSE
# 4997          100.00               54.71                83.75         CBSE
# 4998           83.31               73.93                57.39         CBSE
# 4999           60.13               76.31                66.15        State
#
# ...

# %%
dataset.drop_duplicates(inplace=True)

# %%
dataset.rename(columns={'jee_main_score':'main_score'})
# Out:
#       main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0          78.95               59.22                59.86         CBSE
# 1          70.06               58.75                64.33        State
# 2          81.07               37.27                60.83         ICSE
# 3          93.32               60.72                69.33         ICSE
# 4          68.72               77.73                82.37         CBSE
# ...          ...                 ...                  ...          ...
# 4995       71.31               86.82                57.08        State
# 4996       81.96               34.03                82.85         CBSE
# 4997      100.00               54.71                83.75         CBSE
# 4998       83.31               73.93                57.39         CBSE
# 4999       60.13               76.31                66.15        State
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   jee_main_score        5000 non-null   float64
#  1   jee_advanced_score    5000 non-null   float64
#  2   mock_test_score_avg   5000 non-null   float64
#  3   school_board          5000 non-null   object
#  4   class_12_percent      5000 non-null   float64
#  5   attempt_count         5000 non-null   int64
#  6   coaching_institute    3791 non-null   object
#  7   daily_study_hours     5000 non-null   float64
#  8   family_income         5000 non-null   object
#  9   parent_education      5000 non-null   object
#  10  location_type         5000 non-null   object
#  11  peer_pressure_level   5000 non-null   object
#  12  mental_health_issues  5000 non-null   object
#  13  admission_taken       5000 non-null   object
#  14  dropout               5000 non-null   int64
# ...

# %%
dataset.columns
# Out:
# Index(['jee_main_score', 'jee_advanced_score', 'mock_test_score_avg',
#        'school_board', 'class_12_percent', 'attempt_count',
#        'coaching_institute', 'daily_study_hours', 'family_income',
#        'parent_education', 'location_type', 'peer_pressure_level',
#        'mental_health_issues', 'admission_taken', 'dropout'],
#       dtype='object')

# %%
dataset.map(type)
# Out:
#        jee_main_score jee_advanced_score mock_test_score_avg   school_board  \
# 0     <class 'float'>    <class 'float'>     <class 'float'>  <class 'str'>
# 1     <class 'float'>    <class 'float'>     <class 'float'>  <class 'str'>
# 2     <class 'float'>    <class 'float'>     <class 'float'>  <class 'str'>
# 3     <class 'float'>    <class 'float'>     <class 'float'>  <class 'str'>
# 4     <class 'float'>    <class 'float'>     <class 'float'>  <class 'str'>
# ...               ...                ...                 ...            ...
# 4995  <class 'float'>    <class 'float'>     <class 'float'>  <class 'str'>
# 4996  <class 'float'>    <class 'float'>     <class 'float'>  <class 'str'>
# 4997  <class 'float'>    <class 'float'>     <class 'float'>  <class 'str'>
# 4998  <class 'float'>    <class 'float'>     <class 'float'>  <class 'str'>
# 4999  <class 'float'>    <class 'float'>     <class 'float'>  <class 'str'>
#
# ...

# %%
dataset.query('jee_main_score>1',inplace=True)

# %%
dataset.sort_values(by='jee_main_score')
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 262            26.62               70.36                75.09        State
# 4779           27.53               71.90                62.12         ICSE
# 4725           27.61               61.21                95.65         ICSE
# 2024           29.73               84.20                79.59         ICSE
# 4198           29.89               26.20                69.21         CBSE
# ...              ...                 ...                  ...          ...
# 3659          100.00               68.02                70.40         CBSE
# 3686          100.00               48.06                78.89         CBSE
# 113           100.00               43.53                69.07        State
# 3716          100.00               76.31                79.36         ICSE
# 3717          100.00               68.34                77.85        State
#
# ...

# %%
dataset[['jee_main_score','class_12_percent']].corr()
# Out:
#                   jee_main_score  class_12_percent
# jee_main_score          1.000000         -0.007876
# class_12_percent       -0.007876          1.000000

# %%
b=dataset['jee_main_score'].values
s=nd.sum(b,axis=0)
print(s)#2
# Out:
# 359806.13

# %%
dataset.shift()
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0                NaN                 NaN                  NaN         None
# 1              78.95               59.22                59.86         CBSE
# 2              70.06               58.75                64.33        State
# 3              81.07               37.27                60.83         ICSE
# 4              93.32               60.72                69.33         ICSE
# ...              ...                 ...                  ...          ...
# 4995           62.80               85.11                64.35        State
# 4996           71.31               86.82                57.08        State
# 4997           81.96               34.03                82.85         CBSE
# 4998          100.00               54.71                83.75         CBSE
# 4999           83.31               73.93                57.39         CBSE
#
# ...

# %%
dataset.at[0,'jee_main_score']=10

# %%
dataset.groupby('jee_main_score')['class_12_percent'].mean()
# Out:
# jee_main_score
# 10.00     70.090000
# 26.62     82.300000
# 27.53     68.950000
# 27.61     81.770000
# 29.73     72.360000
#             ...
# 99.82     62.520000
# 99.88     70.240000
# 99.90     87.410000
# 99.94     75.010000
# 100.00    73.287857
# Name: class_12_percent, Length: 3114, dtype: float64

# %%
dataset.iloc[:3]
# Out:
#    jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0           10.00               59.22                59.86         CBSE
# 1           70.06               58.75                64.33        State
# 2           81.07               37.27                60.83         ICSE
#
#    class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0             70.09              1            FIITJEE                5.4
# 1             78.00              1            FIITJEE                5.5
# 2             64.36              1            FIITJEE                7.0
#
#   family_income parent_education location_type peer_pressure_level  \
# 0           Low        Upto 10th         Urban                 Low
# 1           Mid        Upto 10th         Urban                 Low
# 2           Low               PG    Semi-Urban              Medium
#
#   mental_health_issues admission_taken  dropout
# 0                   No              No        1
# ...

# %%
dataset.sample()
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 3480           67.77               60.85                93.32         ICSE
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 3480             81.84              1              Local                5.7
#
#      family_income parent_education location_type peer_pressure_level  \
# 3480          High             12th         Rural                 Low
#
#      mental_health_issues admission_taken  dropout
# 3480                  Yes             Yes        0

# %%
dataset.nlargest(5,'jee_main_score')
# Out:
#      jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 113           100.0               43.53                69.07        State
# 125           100.0               55.06                66.47        State
# 179           100.0               66.25                81.42        State
# 209           100.0               67.00                59.74         CBSE
# 220           100.0               94.56                83.79        State
#
#      class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 113             67.05              1                NaN                6.6
# 125             76.06              2              Local                2.7
# 179             57.81              1              Allen                2.1
# 209             76.67              2            FIITJEE                6.6
# 220             67.45              1              Local                6.5
#
# ...

# %%
x=nd.array([1,2,3,4,5]) #what is positive correlation and negative correlation
y=nd.array([1,2,3,4,5])
md.scatter(x,y)
md.title("Graph")
md.show()

# %%
dataset['attempt_count'].equals(dataset['class_12_percent'])
# Out:
# False
